# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Clean input
# we can get the 10 images from 1 image by changing the property of it

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
