# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2 types of functions
# 1. built in
# 2. user define

# %% [markdown]
# #### Built in  functions

# %%
a=4
b=5
print(max(a,b))
print(min(a, b))
# Out:
# 5
# 4

# %% [markdown]
# #### User Defined functions

# %%
def sum(a, b):
    return a+b
output= sum(2,3)
print(output)
# Out:
# 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## List
# ![image.png](attachment:image.png)

# %%
my_list=[1, 2, 3]
print(my_list[-1])
# Out:
# 3

# %% [markdown]
# #### Tuple
# same like list however cannot be updated
# ![image.png](attachment:image.png)

# %%
my_tuple=(100,10,1)
print(my_tuple)
# Out:
# (100, 10, 1)

# %% [markdown]
# #### Set
# can not take duplicate
# also indexing does not exist
# ![image.png](attachment:image.png)

# %%
my_set={1,2,3,4,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dictionary is a key value pair

# %%
my_dict={"fruit1":"apple",
"fruit2": "mango"
}
#print(my_dict[fruit1])
