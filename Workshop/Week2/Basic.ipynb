# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Python is equipped with rich ecosystem of libraries and framework. such as TensorFlow, PyTorch, and HuggingFace Transformer
# Many top tech companies like FAANG(Biggest motivation)
