# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Clean input
# we can get the 10 images from 1 image by changing the property of it

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 2 NN works together
# 1 generator create fake image
# discriminator distinguish between fake and real images

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# reduce dimensionality for faster operations
# to detect anomilies by VAEs by comparing the input to the learn distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# StyleGAN is used to increase the image data
