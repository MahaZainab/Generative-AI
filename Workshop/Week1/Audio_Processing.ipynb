# %%
Au

# %% [markdown]
# Audio sample
# Resample to make them resample on the same timme
# ![image.png](attachment:image.png)

# %% [markdown]
# then trime slice
# normalize
# standarization to varri
# pad(short) and the turncate(long)
# standardization produced mean-centered data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Need GPU to process
# create latency in real time speeh recognition
# can be reduced using good hardware and preprocessing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Accents
