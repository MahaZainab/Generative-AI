# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=10 #right way to declare variable
a_b = 20 #right way to declare variable

# %%
a=10
print(type(a))
b=2.2
print(type(b))
c="Hello"
print(type(c))
d=True
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# sum 
a=5
b=4
print("a+b", a+b)
print("a-b", a-b)
print("a*b", a*b)
print("a/b", a/b)
print("a%b", a%b)
print("a//b Integer division", a//b)
print("a**b Power", a**b)
# Out:
# a+b 9
# a-b 1
# a*b 20
# a/b 1.25
# a%b 1
# a//b Integer division 1
# a**b Power 625
