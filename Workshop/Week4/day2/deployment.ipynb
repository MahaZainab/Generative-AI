# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# retool where we can use to deploy our app and can deploy and connect database

# %% [markdown]
# https://huggingface.co/runwayml/stable-diffusion-v1-5

# %% [markdown]
# OpenCV, add an overly on video and image

# %% [markdown]
# Kaggle gives us 30hour GPU for one week
