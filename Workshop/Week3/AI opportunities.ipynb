# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Types of ML
# 1. Supervised: labeled data
# 2. Unsupervised Learning: unlabeled, cluster
# 3. Reinforcement Learning, Learn by trail and error
# 4. Deep learning: identify patterns in the data using neural networks

# %% [markdown]
# ### Large Language Models(LLMs)
# types of DL models and designed to understand and generate human language
# e.g. GPT-4, BERT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### How to interact with these models
# 1. Chat Interface: ChatGPT, Google Gemini
# 2. LLM APIs: GPT(3.5, 4, turbo), Gemini, Mistral, Whisper
# 3. Specialized Model: YOLO(Object detection), Google T5 based, Whisper

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calling API  of LLMS can be slower bacause it is not running on my system

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
import openai
openai.api_key= os.gerenv("key")
prompt="Hello"
completion= openai.ChatCompletion.create(
    
)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Hugging Face")
