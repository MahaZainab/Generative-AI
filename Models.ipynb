# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# LLMS do the  positional encoding to see the similarity flow

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Beam search : Top k probablity
# top-k sampling: 90% probability
