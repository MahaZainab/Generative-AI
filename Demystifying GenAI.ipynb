# %% [markdown]
# # Demystifying Gen AI
# Module 2

# %% [markdown]
# # Opening the balck box of GPT
# #Preprocessing input for fine-tuning
# # Diving into models
# # Recognizing and avoiding Pitfalls

# %% [markdown]
# # GPT is based on transformer
# ##  Generative  produce output(text image)
# ## pretrained ALready trained on large corpus, can also be fine tuned
# ## transformer ( Paper must read: attention is all you need)
# The core neural network architecture that every generative model is build on

# %% [markdown]
# ## Tokens
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Embadding is basically encoding chunks into vectors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Self attention vector talk to each other and see what is the possiblity of word

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### then pass the vectores to neural networks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# then pick the highest probability of word and then it will return

# %% [markdown]
# 2 ways to manage latency

# %% [markdown]
# software operation are fast and the GPUs are designed to simple calculation on parallel, this way latency is managed

# %% [markdown]
# #### Clean input
# remove stop words
# e.g. a the an
# NLTK is the library to remove them
# First tokenize which is .split()
# then remove the stop words but before change it to lower case

# %%
### Then do the stemming
## a way to remove prefix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# One pitfall could be may be remove the word into the word that may not exist
# e.g. university univers

# %% [markdown]
# ## Lematization
# know little bit context
# can be done using NLTK

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Lemmatization is not a king
# computationally is expensive
# Application like NLP and IR can use it

# %% [markdown]
# other techniques
# wise to remove regular expressions
# just do pattern matching
# if character exist then accept otherwise discard
# #### Python have built in regex library

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Overfitting is not encouraged and used balanced data
# fine tuning is important

# %% [markdown]
# # Vector DB

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# RAGS are build on Vector DB
# ![image.png](attachment:image.png)

# %% [markdown]
# 2 main modules
#  Retriever: Take data from vector DB
#  Generator: generates relavant data based on the retrieve documents in context of the input query using GPT3
